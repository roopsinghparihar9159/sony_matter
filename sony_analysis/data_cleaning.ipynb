# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('rai_dataset.csv')
df.head()
# Out:
#   casted  convivaSessionId   chipset  bufferStatus  bitRate  startFrameNumber  \
# 0  False               0.0   trinket          -1.0     -1.0              -1.0
# 1  False               0.0    sdm845          27.0   5371.0              -1.0
# 2  False               0.0    sdm845          -1.0     -1.0              -1.0
# 3  False               0.0   panther          -1.0     -1.0              -1.0
# 4  False               0.0  Spacewar          94.0   1608.0             136.0
#
#   adOrVideo          deviceDetails     contentID qualityResolution  ...  \
# 0       NaN         vivo 1935 vivo  1.000106e+09               NaN  ...
# 1     Video  ONEPLUS A6000 OnePlus  1.000228e+09               NaN  ...
# 2       NaN  ONEPLUS A6010 OnePlus  1.000229e+09               NaN  ...
# 3       NaN         Pixel 7 Google  1.000229e+09               NaN  ...
# 4     Video           A063 Nothing  1.000229e+09          1280x720  ...
#
# ...

# %%
df.shape
# Out:
# (3297, 62)

# %%
df['date'] = pd.to_datetime(df['timestamp']).dt.date
df['time'] = pd.to_datetime(df['timestamp']).dt.time

# %%
date1 = df['date']
time1 = df['time']

# %%
df1 = pd.DataFrame({'Date':date1,'Time':time1})
df1
# Out:
#            Date      Time
# 0    2023-07-26  18:32:14
# 1    2023-07-26  21:26:32
# 2    2023-07-27  00:57:39
# 3    2023-07-27  01:22:25
# 4    2023-07-27  00:34:54
# ...         ...       ...
# 3292 2023-07-27  16:45:22
# 3293 2023-07-27  06:32:28
# 3294 2023-07-27  06:33:22
# 3295 2023-07-27  13:32:28
# 3296 2023-07-27  08:07:41
#
# [3297 rows x 2 columns]

# %%
df['timestamp1']=pd.to_datetime(df1.Date.astype(str)+' '+df1.Time.astype(str))

# %%
# df['timestamp1'] = pd.to_datetime(df['date'] + ' ' + df['time'])
df.tail()
# Out:
#      casted  convivaSessionId      chipset  bufferStatus  bitRate  \
# 3292    NaN               NaN  Mali-450 MP          -1.0      NaN
# 3293  False               NaN    Apple GPU          -1.0      NaN
# 3294  False               NaN    Apple GPU          -1.0      NaN
# 3295  False               NaN    Apple GPU          -1.0      NaN
# 3296  False               NaN    Apple GPU          -1.0      NaN
#
#       startFrameNumber adOrVideo  \
# 3292               NaN     video
# 3293              25.0     Video
# 3294              25.0     Video
# 3295              25.0     Video
# 3296              25.0     Video
#
#                                           deviceDetails     contentID  \
# 3292  Mozilla/5.0 (Linux armv7l) AppleWebKit/537.36 ...  1.000062e+09
# 3293  5.0 (iPhone; CPU iPhone OS 16_3_1 like Mac OS ...  1.000228e+09
# 3294  5.0 (iPhone; CPU iPhone OS 16_3_1 like Mac OS ...  1.000228e+09
# 3295  5.0 (iPhone; CPU iPhone OS 16_5_1 like Mac OS ...  1.000228e+09
# ...

# %%
df.to_csv('timestamp1.csv')

# %%
# df.inserted_at
# df['Dates_inserted_at'] = pd.to_datetime(df['inserted_at']).dt.date
df['Time_inserted_at'] = pd.to_datetime(df['inserted_at']).dt.time

# %%
df.head()
# Out:
#   casted  convivaSessionId   chipset  bufferStatus  bitRate  startFrameNumber  \
# 0  False               0.0   trinket          -1.0     -1.0              -1.0
# 1  False               0.0    sdm845          27.0   5371.0              -1.0
# 2  False               0.0    sdm845          -1.0     -1.0              -1.0
# 3  False               0.0   panther          -1.0     -1.0              -1.0
# 4  False               0.0  Spacewar          94.0   1608.0             136.0
#
#   adOrVideo          deviceDetails     contentID qualityResolution  ...  \
# 0       NaN         vivo 1935 vivo  1.000106e+09               NaN  ...
# 1     Video  ONEPLUS A6000 OnePlus  1.000228e+09               NaN  ...
# 2       NaN  ONEPLUS A6010 OnePlus  1.000229e+09               NaN  ...
# 3       NaN         Pixel 7 Google  1.000229e+09               NaN  ...
# 4     Video           A063 Nothing  1.000229e+09          1280x720  ...
#
#       packName         playerSource customLog timestamp_fe  \
# ...

# %%
date2 = df['Dates_inserted_at']
time2 = df['Time_inserted_at']

# %%
df2 = pd.DataFrame({'Date':date2,'Time':time2})
df2
# Out:
#             Date             Time
# 0     2023-07-27  00:02:14.365154
# 1     2023-07-27  02:56:33.212097
# 2     2023-07-27  06:27:39.935419
# 3     2023-07-27  06:52:25.818630
# 4     2023-07-27  06:04:55.011682
# ...          ...              ...
# 3292  2023-07-27  22:15:22.446977
# 3293  2023-07-27  12:02:28.259608
# 3294  2023-07-27  12:03:22.720804
# 3295  2023-07-27  19:02:28.418978
# 3296  2023-07-27  13:37:42.212386
#
# [3297 rows x 2 columns]

# %%
df['inserted_at1']=pd.to_datetime(df2.Date.astype(str)+' '+df2.Time.astype(str))

# df['Dates'] = pd.to_datetime(df['date']).dt.date
# df['Time'] = pd.to_datetime(df['date']).dt.time

# %%
df.head()
# Out:
#   casted  convivaSessionId   chipset  bufferStatus  bitRate  startFrameNumber  \
# 0  False               0.0   trinket          -1.0     -1.0              -1.0
# 1  False               0.0    sdm845          27.0   5371.0              -1.0
# 2  False               0.0    sdm845          -1.0     -1.0              -1.0
# 3  False               0.0   panther          -1.0     -1.0              -1.0
# 4  False               0.0  Spacewar          94.0   1608.0             136.0
#
#   adOrVideo          deviceDetails     contentID qualityResolution  ...  \
# 0       NaN         vivo 1935 vivo  1.000106e+09               NaN  ...
# 1     Video  ONEPLUS A6000 OnePlus  1.000228e+09               NaN  ...
# 2       NaN  ONEPLUS A6010 OnePlus  1.000229e+09               NaN  ...
# 3       NaN         Pixel 7 Google  1.000229e+09               NaN  ...
# 4     Video           A063 Nothing  1.000229e+09          1280x720  ...
#
#           playerSource customLog timestamp_fe  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3297 entries, 0 to 3296
# Data columns (total 68 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   casted                   3044 non-null   object
#  1   convivaSessionId         2844 non-null   float64
#  2   chipset                  3296 non-null   object
#  3   bufferStatus             3296 non-null   float64
#  4   bitRate                  1347 non-null   float64
#  5   startFrameNumber         3104 non-null   float64
#  6   adOrVideo                2535 non-null   object
#  7   deviceDetails            3296 non-null   object
#  8   contentID                3294 non-null   float64
#  9   qualityResolution        1578 non-null   object
#  10  videoState               3293 non-null   object
#  11  downloadBandwidth        3226 non-null   object
#  12  appVersion               3296 non-null   object
#  13  networkStrength          2472 non-null   object
# ...

# %%
df['inserted_at'] = df['inserted_at1']

# %%
df['timestamp'] = df['timestamp1']

# %%
df.to_csv('ins_time_update.csv')

# %%
df_new = df

# %%
df_new.drop(['date','time','timestamp1','Dates_inserted_at','Time_inserted_at','inserted_at1'],axis=1,inplace=True)

# %%
df_new.to_csv('final_data.csv')
