# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('rai_dataset.csv')
df.head()
# Out:
#   casted  convivaSessionId   chipset  bufferStatus  bitRate  startFrameNumber  \
# 0  False               0.0   trinket          -1.0     -1.0              -1.0
# 1  False               0.0    sdm845          27.0   5371.0              -1.0
# 2  False               0.0    sdm845          -1.0     -1.0              -1.0
# 3  False               0.0   panther          -1.0     -1.0              -1.0
# 4  False               0.0  Spacewar          94.0   1608.0             136.0
#
#   adOrVideo          deviceDetails     contentID qualityResolution  ...  \
# 0       NaN         vivo 1935 vivo  1.000106e+09               NaN  ...
# 1     Video  ONEPLUS A6000 OnePlus  1.000228e+09               NaN  ...
# 2       NaN  ONEPLUS A6010 OnePlus  1.000229e+09               NaN  ...
# 3       NaN         Pixel 7 Google  1.000229e+09               NaN  ...
# 4     Video           A063 Nothing  1.000229e+09          1280x720  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3297 entries, 0 to 3296
# Data columns (total 62 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   casted                   3044 non-null   object
#  1   convivaSessionId         2844 non-null   float64
#  2   chipset                  3296 non-null   object
#  3   bufferStatus             3296 non-null   float64
#  4   bitRate                  1347 non-null   float64
#  5   startFrameNumber         3104 non-null   float64
#  6   adOrVideo                2535 non-null   object
#  7   deviceDetails            3296 non-null   object
#  8   contentID                3294 non-null   float64
#  9   qualityResolution        1578 non-null   object
#  10  videoState               3293 non-null   object
#  11  downloadBandwidth        3226 non-null   object
#  12  appVersion               3296 non-null   object
#  13  networkStrength          2472 non-null   object
# ...

# %%
df_na = df.isna().sum()

# %%
df_na.to_csv('na_values.csv')

# %%
df['chipset'].unique()
# Out:
# array(['trinket', 'sdm845', 'panther', 'Spacewar', 'k65v1_32_bsp_2g_ago',
#        'lahaina', 'sweetin', 'holi', 'mt6750', 'k6893v1_64_k419',
#        'kalama', 'RM6833', 'RM6785', 'dandelion', 'exynos9610', 'kona',
#        'lito', 'STK-L22HN', 'sunny', 'a13x', 'universal7870', 'msmnile',
#        'exynos2100', 'exynos9810', 'taro', 'vili', 'RM6771_18601', 'spes',
#        'RM6877', 'begoniain', 'k6895v1_64', 'excalibur',
#        'k6877v1_64_k419', 's5e8825', 'sdm636', 'k6886v1_64', 'bluejay',
#        'atoll', 'sdm660', 'QC_Reference_Phone', 'k6833v1_64_k419',
#        'msm8953', 'liber', 'exynos850', 'k79v1_64', 'curtana', 'oppo6771',
#        'sm6150', 'miel', 'gram', 's5e8535', 'msm8998', 'cattail',
#        'sunfish', 'exynos9611', 'dubai', 'hanoip', 'k6893v1_64', 'a12',
#        'violet', 'rhode', 'm53x', 'sdm710', 'bengal', 'Infinix-X6812',
#        'pissarroin', 'vicky', 'fog', 'k65v1_64_bsp', 'ginkgo', 'oriole',
# ...

# %%
for col in df
df['startFrameNumber']=df['startFrameNumber'].fillna(method='ffill')

# %%
df['startFrameNumber'].isna().sum()
# Out:
# 0

# %%
df.head()
# Out:
#   casted  convivaSessionId   chipset  bufferStatus  bitRate  startFrameNumber  \
# 0  False               0.0   trinket          -1.0     -1.0              -1.0
# 1  False               0.0    sdm845          27.0   5371.0              -1.0
# 2  False               0.0    sdm845          -1.0     -1.0              -1.0
# 3  False               0.0   panther          -1.0     -1.0              -1.0
# 4  False               0.0  Spacewar          94.0   1608.0             136.0
#
#   adOrVideo          deviceDetails     contentID qualityResolution  ...  \
# 0       NaN         vivo 1935 vivo  1.000106e+09               NaN  ...
# 1     Video  ONEPLUS A6000 OnePlus  1.000228e+09               NaN  ...
# 2       NaN  ONEPLUS A6010 OnePlus  1.000229e+09               NaN  ...
# 3       NaN         Pixel 7 Google  1.000229e+09               NaN  ...
# 4     Video           A063 Nothing  1.000229e+09          1280x720  ...
#
# ...
